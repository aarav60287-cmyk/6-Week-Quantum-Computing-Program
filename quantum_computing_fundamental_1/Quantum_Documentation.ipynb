# %% [markdown]
# ### What problem is your problem trying to solve?
#
# #### We are attempign to sovle a major problem whre attackers and advertisers harvest ecrypted data and store them in huge libries to dycript when quantum computers get better.
#
# ### What would a classical computer assume aobut this problem that isn't true?
#
# #### Classical computing operates under the assumption that cryptographic security is static: as long as a key is computationally impossible to brute-force line-by-line right now, the data is completely secure. It fails to account for future computational shifts. Classical systems treat encrypted traffic as a temporary event that expires after transmission, assuming an unreadable file stolen today is a useless file forever.
#
# ### What does your project see that only makes sense if you stop thinking in straight lines?
#
# #### Our project sees that a cyber breach can happen years before the data is actually read. Straight-line thinking assumes a timeline where Attack → Decryption → Damage all happen at the same time. Non-linear thinking reveals three key twists:
