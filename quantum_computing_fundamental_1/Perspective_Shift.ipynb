# %% [markdown]
# ### What's one thing he said that connects to something you've already lived through — not in a classroom, in your actual life?
#
# #### One thing AM said that stuck with me was, "Paris is beautiful in the spring." It made me think about how you don't really understand something until you experience it yourself. That's happened to me a lot when I'm learning new things. I ask questions and figure things out instead of just believing what I'm told, kind of like what Socrates believed.
#
# ---
#
# ### Think of a decision you made where you couldn't know the outcome until you committed to it. How is that like measurement collapsing a qubit?
#
# #### A decision I made was choosing my classes for the school year. Before I picked them, I didn't know if I would like the teachers or the work. Once I chose my classes, I found out the outcome, it was alright, I will never forget how Ms Y**** graded my work. This is like measuring a qubit because both involve many possibilities until one final result is revealed.
#
# ---
#
# ### When has being observed changed how you performed? That's the measurement problem. It's not just physics.
#
# #### During track tryouts, I ran faster because I knew the coaches were watching. I pushed myself more than I would have at a normal practice. Being watched changed how I performed, kind of like how measuring something can affect the result.
